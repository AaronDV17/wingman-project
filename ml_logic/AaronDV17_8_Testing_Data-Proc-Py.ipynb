# %%
from preprocessor import preprocess_features
import pandas as pd
import numpy as np

# %%
wingman_df = pd.read_csv('../raw_data/trimmed_data/wingman_data_cleaned.csv')

mask = wingman_df['hp_or_lbs'] == 'HP'

wingman_df = wingman_df[mask]

wingman_df.drop(columns=['hp_or_lbs'], axis=1, inplace=True)

wingman_df['power_units'].fillna(wingman_df['power_units'].median(), inplace=True)

wingman_df.set_index('id', inplace=True)

# %%
wingman_df.head()
# Out:
#                  eventsoe_no far_part               acft_make acft_model  \
# id
# 20080107X000261          250      091                   PIPER  PA 28-180
# 20080107X000262          250      091         Barnard/Stancil    Glastar
# 20080109X000361          230      091  Micco Aircraft Company   MAC-145B
# 20080107X000271           81      091                 Pilatus   PC-12/45
# 20080115X000511          240      091                  Cessna        152
#
#                 fixed_retractable acft_category homebuilt  flight_hours_mean  \
# id
# 20080107X000261              FIXD           AIR         N              705.0
# 20080107X000262              FIXD           AIR         Y             8300.0
# 20080109X000361              RETR           AIR         N             1000.0
# 20080107X000271              RETR           AIR         N            10571.0
# 20080115X000511              FIXD           AIR         N               18.0
#
# ...

# %%
wng_proc = preprocess_features(wingman_df)
wng_proc
# Out:
# /home/givenkiban1/lewagon/wingman-project/ml_logic/encoders.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wingman_data_enc[''] = np.where(wingman_data_enc['type_fly'].isin(top_9_categories), wingman_data_enc['type_fly'], 'Other')
# /home/givenkiban1/lewagon/wingman-project/ml_logic/encoders.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eng_mfgr['eng_mfgr'] = eng_mfgr['eng_mfgr'].str.upper()
# ...

# %%
wng_proc[['dprt_apt_id']]

# %%
wng_proc['dprt_apt_id'].value_counts()

# %%
wng_proc['dest_apt_id'].value_counts()

# %%
wng_proc['dest_apt_id'].isnull().sum()

# %%
wng_proc['dprt_apt_id'].isnull().sum()

# %%
wingman_df['dest_apt_id']

# %%
wingman_df['dest_apt_id'].apply(lambda x: 0 if x in ['NONE', 'PVT'] else 1)

# %%
wingman_df['dest_apt_id'].apply(lambda x: 0 if x in ['NONE', 'PVT'] else 1).value_counts()
