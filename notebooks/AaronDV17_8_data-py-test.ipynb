# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from data import *

# %% [markdown]
# ## Load Data

# %%
wingman_df_trim = pd.read_csv('../raw_data/trimmed_data/wingman_data.csv')

# %% [markdown]
# ## Testing

# %% [markdown]
# ### Original Data (Selection from base data)

# %%
wingman_df_trim
# Out:
#                     id  eventsoe_no far_part flt_plan_filed  \
# 0      20080107X000261          250      091           NONE
# 1      20080107X000262          250      091           NONE
# 2      20080109X000361          230      091           NONE
# 3      20080107X000271           81      091            IFR
# 4      20080115X000511          240      091           NONE
# ...                ...          ...      ...            ...
# 18806  202303131068841           96      091           NONE
# 18807  202303131068851          191      091            IFR
# 18808  202303241069471           96      091           NONE
# 18809  202303311069871          193      137           NONE
# 18810  202304101070311          230      091           NONE
#
#                     acft_make     acft_model  total_seats  num_eng  \
# 0                       PIPER      PA 28-180          4.0      1.0
# 1             Barnard/Stancil        Glastar          2.0      1.0
# ...

# %%
wingman_df_trim.columns
# Out:
# Index(['id', 'eventsoe_no', 'far_part', 'flt_plan_filed', 'acft_make',
#        'acft_model', 'total_seats', 'num_eng', 'fixed_retractable',
#        'cert_max_gr_wt', 'acft_category', 'homebuilt', 'type_last_insp',
#        'afm_hrs_last_insp', 'afm_hrs', 'elt_install', 'elt_type', 'oper_dba',
#        'certs_held', 'type_fly', 'second_pilot', 'dprt_apt_id', 'dprt_time',
#        'dest_apt_id', 'site_seeing', 'air_medical', 'flight_hours_mean',
#        'crew_category', 'crew_sex', 'pc_profession', 'crew_tox_perf',
#        'mr_faa_med_certf', 'available_restraint', 'eng_no', 'eng_type',
#        'eng_mfgr', 'eng_model', 'power_units', 'hp_or_lbs',
#        'carb_fuel_injection', 'propeller_type'],
#       dtype='object')

# %%
wingman_df_trim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18811 entries, 0 to 18810
# Data columns (total 41 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   18811 non-null  object
#  1   eventsoe_no          18811 non-null  int64
#  2   far_part             18811 non-null  object
#  3   flt_plan_filed       18614 non-null  object
#  4   acft_make            18810 non-null  object
#  5   acft_model           18810 non-null  object
#  6   total_seats          17472 non-null  float64
#  7   num_eng              18419 non-null  float64
#  8   fixed_retractable    18811 non-null  object
#  9   cert_max_gr_wt       15700 non-null  float64
#  10  acft_category        18810 non-null  object
#  11  homebuilt            18811 non-null  object
#  12  type_last_insp       17355 non-null  object
#  13  afm_hrs_last_insp    6437 non-null   float64
#  14  afm_hrs              15551 non-null  float64
# ...

# %%
wingman_df_trim.nunique()
# Out:
# id                     18811
# eventsoe_no               88
# far_part                  16
# flt_plan_filed             7
# acft_make               3397
# acft_model              4385
# total_seats              155
# num_eng                    6
# fixed_retractable          2
# cert_max_gr_wt          1497
# acft_category             12
# homebuilt                  2
# type_last_insp             6
# afm_hrs_last_insp        802
# afm_hrs                10482
# elt_install                2
# elt_type                   4
# oper_dba                 831
# certs_held                 1
# type_fly                  24
# second_pilot               2
# dprt_apt_id             5847
# dprt_time               1124
# dest_apt_id             5381
# site_seeing                2
# air_medical                2
# flight_hours_mean       7534
# crew_category              5
# crew_sex                   2
# pc_profession              3
# crew_tox_perf              2
# mr_faa_med_certf           9
# ...

# %%
wingman_df_trim.isnull().sum().sort_values(ascending=False)
# Out:
# mr_faa_med_certf       18550
# oper_dba               17773
# afm_hrs_last_insp      12374
# propeller_type         11077
# available_restraint     8338
# elt_type                7796
# dest_apt_id             3666
# carb_fuel_injection     3666
# dprt_time               3627
# afm_hrs                 3260
# crew_sex                3218
# cert_max_gr_wt          3111
# dprt_apt_id             2371
# elt_install             1969
# crew_tox_perf           1607
# hp_or_lbs               1561
# type_last_insp          1456
# power_units             1377
# total_seats             1339
# second_pilot            1127
# type_fly                1085
# pc_profession            600
# certs_held               407
# num_eng                  392
# eng_model                222
# flt_plan_filed           197
# eng_mfgr                 109
# eng_type                  75
# air_medical               25
# site_seeing               17
# acft_make                  1
# acft_category              1
# ...

# %%
# Null values for each column by percent
wingman_df_trim.isnull().sum().sort_values(ascending=False) / len(wingman_df_trim) * 100
# Out:
# mr_faa_med_certf       98.612514
# oper_dba               94.481952
# afm_hrs_last_insp      65.780660
# propeller_type         58.885758
# available_restraint    44.325129
# elt_type               41.443836
# dest_apt_id            19.488597
# carb_fuel_injection    19.488597
# dprt_time              19.281272
# afm_hrs                17.330285
# crew_sex               17.107012
# cert_max_gr_wt         16.538196
# dprt_apt_id            12.604327
# elt_install            10.467280
# crew_tox_perf           8.542874
# hp_or_lbs               8.298336
# type_last_insp          7.740152
# power_units             7.320185
# total_seats             7.118176
# second_pilot            5.991175
# type_fly                5.767902
# pc_profession           3.189623
# certs_held              2.163628
# num_eng                 2.083887
# eng_model               1.180161
# flt_plan_filed          1.047260
# eng_mfgr                0.579448
# eng_type                0.398703
# ...

# %% [markdown]
# ### Process

# %%
wing_clean = clean_data(wingman_df_trim)
# Out:
# /home/aaron/code/AaronDV17/wingman-project/ml_logic/data.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wingman_data_cleaned.drop([

# %% [markdown]
# ### Cleaned Data

# %%
# Set the index to the 'id' column
wing_clean.set_index('id', inplace=True)

# %%
wing_clean
# Out:
#                  eventsoe_no far_part               acft_make  \
# id
# 20080107X000261          250      091                   PIPER
# 20080107X000262          250      091         Barnard/Stancil
# 20080109X000361          230      091  Micco Aircraft Company
# 20080107X000271           81      091                 Pilatus
# 20080115X000511          240      091                  Cessna
# ...                      ...      ...                     ...
# 20200616X024101          220      137             Air Tractor
# 20200616X529141          341      091                  Cessna
# 20200617X857041          220      091                Robinson
# 20200617X320491           30      091                 DESTINY
# 20200617X528071           92      091                   Piper
#
#                 fixed_retractable acft_category homebuilt  flight_hours_mean  \
# id
# 20080107X000261              FIXD           AIR         N         705.000000
# ...

# %%
wing_clean.columns
# Out:
# Index(['eventsoe_no', 'far_part', 'acft_make', 'fixed_retractable',
#        'acft_category', 'homebuilt', 'flight_hours_mean', 'crew_category',
#        'dprt_time', 'cert_max_gr_wt', 'afm_hrs', 'total_seats', 'power_units',
#        'num_eng', 'type_last_insp', 'second_pilot', 'site_seeing',
#        'air_medical', 'crew_sex', 'certs_held', 'dprt_apt_id', 'dest_apt_id',
#        'flt_plan_filed', 'pc_profession', 'eng_type', 'carb_fuel_injection',
#        'type_fly', 'eng_mfgr'],
#       dtype='object')

# %%
wing_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15072 entries, 20080107X000261 to 20200617X528071
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eventsoe_no          15072 non-null  int64
#  1   far_part             15072 non-null  object
#  2   acft_make            15072 non-null  object
#  3   fixed_retractable    15072 non-null  object
#  4   acft_category        15072 non-null  object
#  5   homebuilt            15072 non-null  object
#  6   flight_hours_mean    15072 non-null  float64
#  7   crew_category        15072 non-null  object
#  8   dprt_time            15072 non-null  int64
#  9   cert_max_gr_wt       15072 non-null  int64
#  10  afm_hrs              15072 non-null  int64
#  11  total_seats          15072 non-null  int64
#  12  power_units          15072 non-null  int64
#  13  num_eng              15072 non-null  int64
#  14  type_last_insp       15072 non-null  object
# ...

# %%
wing_clean.nunique()
# Out:
# eventsoe_no              84
# far_part                 13
# acft_make              2804
# fixed_retractable         2
# acft_category             8
# homebuilt                 2
# flight_hours_mean      6226
# crew_category             5
# dprt_time              1054
# cert_max_gr_wt         1168
# afm_hrs                7078
# total_seats              68
# power_units             404
# num_eng                   5
# type_last_insp            6
# second_pilot              2
# site_seeing               2
# air_medical               2
# crew_sex                  2
# certs_held                2
# dprt_apt_id            5134
# dest_apt_id            4820
# flt_plan_filed            7
# pc_profession             3
# eng_type                  7
# carb_fuel_injection       3
# type_fly                 24
# eng_mfgr                560
# dtype: int64

# %%
wing_clean.isnull().sum().sort_values(ascending=False)
# Out:
# eventsoe_no            0
# far_part               0
# type_fly               0
# carb_fuel_injection    0
# eng_type               0
# pc_profession          0
# flt_plan_filed         0
# dest_apt_id            0
# dprt_apt_id            0
# certs_held             0
# crew_sex               0
# air_medical            0
# site_seeing            0
# second_pilot           0
# type_last_insp         0
# num_eng                0
# power_units            0
# total_seats            0
# afm_hrs                0
# cert_max_gr_wt         0
# dprt_time              0
# crew_category          0
# flight_hours_mean      0
# homebuilt              0
# acft_category          0
# fixed_retractable      0
# acft_make              0
# eng_mfgr               0
# dtype: int64

# %%
# Null values for each column by percent
wing_clean.isnull().sum().sort_values(ascending=False) / len(wingman_df_trim) * 100
# Out:
# eventsoe_no            0.0
# far_part               0.0
# type_fly               0.0
# carb_fuel_injection    0.0
# eng_type               0.0
# pc_profession          0.0
# flt_plan_filed         0.0
# dest_apt_id            0.0
# dprt_apt_id            0.0
# certs_held             0.0
# crew_sex               0.0
# air_medical            0.0
# site_seeing            0.0
# second_pilot           0.0
# type_last_insp         0.0
# num_eng                0.0
# power_units            0.0
# total_seats            0.0
# afm_hrs                0.0
# cert_max_gr_wt         0.0
# dprt_time              0.0
# crew_category          0.0
# flight_hours_mean      0.0
# homebuilt              0.0
# acft_category          0.0
# fixed_retractable      0.0
# acft_make              0.0
# eng_mfgr               0.0
# dtype: float64

# %% [markdown]
# ### Preprocessing

# %%
from preprocessor import *
