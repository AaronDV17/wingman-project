# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
wingman_data = pd.read_csv('raw_data/wingman_data.csv')

# %%
null = []
for column in wingman_data.columns:
    na = wingman_data[column].isnull().value_counts()
    null.append(na)

# %% [markdown]
# ## Dropping duplicates

# %%
wingman_data = wingman_data.drop_duplicates()

# %% [markdown]
# ## Dropping rows and columns

# %%
wingman_data_cleaned = wingman_data.dropna(subset=['acft_make', 'acft_model', 'acft_category'], how='any')
wingman_data_cleaned.drop(['afm_hrs_last_insp', 'elt_install', 'elt_type', 'oper_dba', 'crew_tox_perf', 'mr_faa_med_certf', 'eng_model', 'propeller_type', 'available_restraint', 'eng_no'], axis=1, inplace=True)
# Out:
# /var/folders/sg/gv4lllxn7vb2bw3h3pf1mndh0000gn/T/ipykernel_62938/286759556.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wingman_data_cleaned.drop(['afm_hrs_last_insp', 'elt_install', 'elt_type', 'oper_dba', 'crew_tox_perf', 'mr_faa_med_certf', 'eng_model', 'propeller_type', 'available_restraint', 'eng_no'], axis=1, inplace=True)

# %%
wingman_data_cleaned.columns
# Out:
# Index(['id', 'eventsoe_no', 'far_part', 'flt_plan_filed', 'acft_make',
#        'acft_model', 'total_seats', 'num_eng', 'fixed_retractable',
#        'cert_max_gr_wt', 'acft_category', 'homebuilt', 'type_last_insp',
#        'afm_hrs', 'certs_held', 'type_fly', 'second_pilot', 'dprt_apt_id',
#        'dprt_time', 'dest_apt_id', 'site_seeing', 'air_medical',
#        'flight_hours_mean', 'crew_category', 'crew_sex', 'pc_profession',
#        'eng_type', 'eng_mfgr', 'power_units', 'hp_or_lbs',
#        'carb_fuel_injection'],
#       dtype='object')

# %% [markdown]
# ## Imputing values

# %%
features_numeric_1 = ['dprt_time']
features_numeric_2 = ['cert_max_gr_wt', 'afm_hrs', 'total_seats']
features_cat = ['num_eng', 'type_last_insp', 'second_pilot', 'site_seeing', 'air_medical', 'crew_sex']
features_certs = ['certs_held']
features_5 = ['dprt_apt_id', 'dest_apt_id', 'flt_plan_filed']
features_6 = ['pc_profession', 'eng_type', 'carb_fuel_injection', 'type_fly']
features_7 = ['eng_mfgr']

# %%
imputer_numeric_1 = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
])

imputer_numeric_2 = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median'))
])

imputer_categoric = Pipeline(
    steps=[('imputer',
            SimpleImputer(strategy='most_frequent'))])

imputer_certs = Pipeline(
    steps=[('imputer',
            SimpleImputer(strategy='constant', fill_value="N"))])

imputer_5 = Pipeline(
    steps=[('imputer',
            SimpleImputer(strategy='constant', fill_value="NONE"))])

imputer_6 = Pipeline(
    steps=[('imputer',
            SimpleImputer(strategy='constant', fill_value="UNK"))])

imputer_7 = Pipeline(
    steps=[('imputer',
            SimpleImputer(strategy='constant', fill_value="Other"))])

# %%
preprocessor = ColumnTransformer(transformers=[('imputer_numeric_1',
                                                imputer_numeric_1,
                                                features_numeric_1),
                                               ('imputer_numeric_2', 
                                                imputer_numeric_2,
                                                features_numeric_2),
                                               ('imputer_categoric',
                                                imputer_categoric,
                                                features_cat),
                                               ('imputer_certs', 
                                               imputer_certs, 
                                               features_certs),
                                               ('imputer_5', 
                                                imputer_5, 
                                                features_5),
                                               ('imputer_6', 
                                                imputer_6, 
                                                features_6),
                                               ('imputer_7', 
                                               imputer_7, 
                                               features_7)])

preprocessor
# Out:
# ColumnTransformer(transformers=[('imputer_numeric_1',
#                                  Pipeline(steps=[('imputer', SimpleImputer())]),
#                                  ['dprt_time']),
#                                 ('imputer_numeric_2',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  ['cert_max_gr_wt', 'afm_hrs', 'total_seats']),
#                                 ('imputer_categoric',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent'))]),
#                                  ['num_eng', 'type_...
#                                                   SimpleImputer(fill_value='NONE',
#                                                                 strategy='constant'))]),
#                                  ['dprt_apt_id', 'dest_apt_id',
#                                   'flt_plan_filed']),
#                                 ('imputer_6',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value='UNK',
#                                                                 strategy='constant'))]),
#                                  ['pc_profession', 'eng_type',
#                                   'carb_fuel_injection', 'type_fly']),
#                                 ('imputer_7',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value='Other',
#                                                                 strategy='constant'))]),
#                                  ['eng_mfgr'])])

# %%
preprocessor.fit(wingman_data_cleaned)

wingman_data_preproc = preprocessor.transform(wingman_data_cleaned)

# %% [markdown]
# ## Merging datasets

# %%
c = ['dprt_time', 'cert_max_gr_wt', 'afm_hrs', 'total_seats', 'num_eng', 'type_last_insp', 'second_pilot', 'site_seeing', 'air_medical', 'crew_sex', 
     'certs_held', 'dprt_apt_id', 'dest_apt_id', 'flt_plan_filed', 'pc_profession', 'eng_type', 'carb_fuel_injection', 'type_fly', 'eng_mfgr']

# %%
wingman_data_preproc = pd.DataFrame(wingman_data_preproc, columns=c)
wingman_data_cleaned = wingman_data_cleaned.drop(columns=c)
wingman_data_cl_imp = pd.merge(wingman_data_cleaned, wingman_data_preproc, left_index=True, right_index=True)

# %% [markdown]
# ## Fixing Dtypes

# %%
wingman_data_cl_imp['total_seats'] = wingman_data_cl_imp['total_seats'].astype('int64')
wingman_data_cl_imp['num_eng'] = wingman_data_cl_imp['num_eng'].astype('int64')
wingman_data_cl_imp['dprt_time'] = wingman_data_cl_imp['dprt_time'].astype('int64')
wingman_data_cl_imp['cert_max_gr_wt'] = wingman_data_cl_imp['cert_max_gr_wt'].astype('int64')
wingman_data_cl_imp['afm_hrs'] = wingman_data_cl_imp['afm_hrs'].astype('int64')

# %% [markdown]
# ## Exporting

# %%
wingman_data_cl_imp.to_csv('/Users/danielderbyshire/Desktop/wingman_data_cleaned.csv')

# %% [markdown]
# ## Exploring dataset

# %%
wingman_data_cl_imp.set_index('id', inplace=True)

wingman_data_cl_imp.select_dtypes(include='object')
# Out:
#                 far_part               acft_make     acft_model  \
# id
# 20080107X000261      091                   PIPER      PA 28-180
# 20080107X000262      091         Barnard/Stancil        Glastar
# 20080109X000361      091  Micco Aircraft Company       MAC-145B
# 20080107X000271      091                 Pilatus       PC-12/45
# 20080115X000511      091                  Cessna            152
# ...                  ...                     ...            ...
# 202303131068811      091                   BEECH           E-55
# 202303131068821      091                 TRENDAK         TAURUS
# 202303131068841      091                   MAULE       M-7-235B
# 202303131068851      091                   BEECH           F33A
# 202303241069471      091          FIEDLER MARK R  PA-18 REPLICA
#
#                 fixed_retractable acft_category homebuilt crew_category  \
# id
# 20080107X000261              FIXD           AIR         N           PLT
# 20080107X000262              FIXD           AIR         Y           PLT
# 20080109X000361              RETR           AIR         N           PLT
# 20080107X000271              RETR           AIR         N           PLT
# 20080115X000511              FIXD           AIR         N          DSTU
# ...                           ...           ...       ...           ...
# 202303131068811              RETR           AIR         N           PLT
# 202303131068821              FIXD          GYRO         Y           PLT
# 202303131068841              FIXD           AIR         N           PLT
# 202303131068851              RETR           AIR         N           PLT
# 202303241069471              FIXD           AIR         Y           PLT
#
#                 hp_or_lbs type_last_insp second_pilot  ... crew_sex  \
# id                                                     ...
# 20080107X000261        HP           ANNL            N  ...        M
# 20080107X000262        HP           COAW            N  ...        M
# 20080109X000361        HP           ANNL            N  ...        F
# 20080107X000271        HP            UNK            N  ...        M
# 20080115X000511        HP           ANNL            N  ...        M
# ...                   ...            ...          ...  ...      ...
# 202303131068811        HP           ANNL            N  ...        M
# 202303131068821        HP           ANNL            N  ...        M
# 202303131068841        HP           COND            N  ...        M
# 202303131068851        HP           ANNL            N  ...        M
# 202303241069471        HP           100H            N  ...        M
#
#                 certs_held dprt_apt_id dest_apt_id flt_plan_filed  \
# id
# 20080107X000261          Y        O69         OQ3            NONE
# 20080107X000262          Y        OQ3         O70            NONE
# 20080109X000361          Y        T20         AXH            NONE
# 20080107X000271          Y        PHX         PWA             IFR
# 20080115X000511          Y        KFNL        KFNL           NONE
# ...                    ...         ...         ...            ...
# 202303131068811          Y        2CO5         PVT           NONE
# 202303131068821          Y         ATW         LOT            IFR
# 202303131068841          Y         3L2        KVGT           NONE
# 202303131068851          Y        NONE        NONE           NONE
# 202303241069471          Y        NONE        NONE           NONE
#
#                 pc_profession eng_type carb_fuel_injection type_fly  \
# id
# 20080107X000261            No      REC                CARB     PERS
# 20080107X000262            No      REC                CARB     PERS
# 20080109X000361            No      REC                FINJ     PERS
# 20080107X000271           UNK       TP                 UNK     PERS
# 20080115X000511            No      REC                CARB     INST
# ...                       ...      ...                 ...      ...
# 202303131068811            No      REC                CARB     PERS
# 202303131068821            No      REC                FINJ     PERS
# 202303131068841           Yes      REC                CARB     PERS
# 202303131068851           Yes       TS                 UNK     AAPL
# 202303241069471            No      REC                CARB     INST
#
#                                eng_mfgr
# id
# 20080107X000261        Textron Lycoming
# 20080107X000262        Textron Lycoming
# 20080109X000361                Lycoming
# 20080107X000271  Pratt & Whitney Canada
# 20080115X000511                Lycoming
# ...                                 ...
# 202303131068811                Lycoming
# 202303131068821             Continental
# 202303131068841                   Titan
# 202303131068851                 ALLISON
# 202303241069471                Lycoming
#
# [18807 rows x 22 columns]

# %%
wingman_data_cl_imp.select_dtypes(include='object').columns
# Out:
# Index(['far_part', 'acft_make', 'acft_model', 'fixed_retractable',
#        'acft_category', 'homebuilt', 'crew_category', 'hp_or_lbs',
#        'type_last_insp', 'second_pilot', 'site_seeing', 'air_medical',
#        'crew_sex', 'certs_held', 'dprt_apt_id', 'dest_apt_id',
#        'flt_plan_filed', 'pc_profession', 'eng_type', 'carb_fuel_injection',
#        'type_fly', 'eng_mfgr'],
#       dtype='object')

# %%
wingman_data_cl_imp.select_dtypes(include='object').columns
# Out:
# Index(['far_part', 'acft_make', 'acft_model', 'fixed_retractable',
#        'acft_category', 'homebuilt', 'crew_category', 'hp_or_lbs',
#        'type_last_insp', 'second_pilot', 'site_seeing', 'air_medical',
#        'crew_sex', 'certs_held', 'dprt_apt_id', 'dest_apt_id',
#        'flt_plan_filed', 'pc_profession', 'eng_type', 'carb_fuel_injection',
#        'type_fly', 'eng_mfgr'],
#       dtype='object')

# %% [markdown]
# ## All steps

# %%
def data_cleaning(X):
    ## drop duplicates
    wingman_data = X.drop_duplicates()

    ## drop rows and columns
    wingman_data_cleaned = wingman_data.dropna(subset=['acft_make', 'acft_model', 'acft_category'], how='any')
    wingman_data_cleaned.drop(['afm_hrs_last_insp', 'elt_install', 'elt_type', 'oper_dba', 'crew_tox_perf', 'mr_faa_med_certf', 'eng_model', 'propeller_type', 'available_restraint', 'eng_no'], axis=1, inplace=True)

    ## imputing
    features_numeric_1 = ['dprt_time']
    features_numeric_2 = ['cert_max_gr_wt', 'afm_hrs', 'total_seats']
    features_cat = ['num_eng', 'type_last_insp', 'second_pilot', 'site_seeing', 'air_medical', 'crew_sex']
    features_certs = ['certs_held']
    features_5 = ['dprt_apt_id', 'dest_apt_id', 'flt_plan_filed']
    features_6 = ['pc_profession', 'eng_type', 'carb_fuel_injection', 'type_fly']
    features_7 = ['eng_mfgr']

    imputer_numeric_1 = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean')),
    ])
    imputer_numeric_2 = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median'))
    ])
    imputer_categoric = Pipeline(
        steps=[('imputer',
                SimpleImputer(strategy='most_frequent'))])
    imputer_certs = Pipeline(
        steps=[('imputer',
                SimpleImputer(strategy='constant', fill_value="N"))])
    imputer_5 = Pipeline(
        steps=[('imputer',
                SimpleImputer(strategy='constant', fill_value="NONE"))])
    imputer_6 = Pipeline(
        steps=[('imputer',
                SimpleImputer(strategy='constant', fill_value="UNK"))])
    imputer_7 = Pipeline(
        steps=[('imputer',
                SimpleImputer(strategy='constant', fill_value="Other"))])

    preprocessor = ColumnTransformer(transformers=[('imputer_numeric_1',
                                                    imputer_numeric_1,
                                                    features_numeric_1),
                                                ('imputer_numeric_2', 
                                                    imputer_numeric_2,
                                                    features_numeric_2),
                                                ('imputer_categoric',
                                                    imputer_categoric,
                                                    features_cat),
                                                ('imputer_certs', 
                                                imputer_certs, 
                                                features_certs),
                                                ('imputer_5', 
                                                    imputer_5, 
                                                    features_5),
                                                ('imputer_6', 
                                                    imputer_6, 
                                                    features_6),
                                                ('imputer_7', 
                                                imputer_7, 
                                                features_7)])
    preprocessor.fit(wingman_data_cleaned)
    wingman_data_preproc = preprocessor.transform(wingman_data_cleaned)
    
    ## merging datasets
    c = ['dprt_time', 'cert_max_gr_wt', 'afm_hrs', 'total_seats', 'num_eng', 'type_last_insp', 'second_pilot', 'site_seeing', 'air_medical', 'crew_sex', 
        'certs_held', 'dprt_apt_id', 'dest_apt_id', 'flt_plan_filed', 'pc_profession', 'eng_type', 'carb_fuel_injection', 'type_fly', 'eng_mfgr']
    wingman_data_preproc = pd.DataFrame(wingman_data_preproc, columns=c)
    wingman_data_cleaned = wingman_data_cleaned.drop(columns=c)
    wingman_data_cl_imp = pd.merge(wingman_data_cleaned, wingman_data_preproc, left_index=True, right_index=True)

    ## fixing dtypes
    wingman_data_cl_imp['total_seats'] = wingman_data_cl_imp['total_seats'].astype('int64')
    wingman_data_cl_imp['num_eng'] = wingman_data_cl_imp['num_eng'].astype('int64')
    wingman_data_cl_imp['dprt_time'] = wingman_data_cl_imp['dprt_time'].astype('int64')
    wingman_data_cl_imp['cert_max_gr_wt'] = wingman_data_cl_imp['cert_max_gr_wt'].astype('int64')
    wingman_data_cl_imp['afm_hrs'] = wingman_data_cl_imp['afm_hrs'].astype('int64')
    
    return wingman_data_cl_imp
